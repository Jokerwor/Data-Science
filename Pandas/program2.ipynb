# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/thousandoaks/Python4DS101/master/data/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name",inplace=True)

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key':[1,2,3,4,5,6],'key2':[7,8,9,10,11,12],'key3':[13,14,15,16,17,18]}

# %%
pd.DataFrame(d)
# Out:
#    key  key2  key3
# 0    1     7    13
# 1    2     8    14
# 2    3     9    15
# 3    4    10    16
# 4    5    11    17
# 5    6    12    18

# %%
pd.read_csv("free-taxonomy.csv")
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
pd.read_csv("free-taxonomy.csv").dropna(inplace= True)

# %%
pd.read_csv("free-taxonomy.csv")
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
pd.read_csv("free-taxonomy.csv").dropna(axis=1)
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %%
df1 = pd.read_csv("free-taxonomy.csv")

# %%
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.dropna(axis=1)
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %%
df1.fillna("rishi")
# Out:
#                         name     id parent_name parent_id  \
# 0                  Emergency   1101           0       0.0
# 1                       Food   1102           0       0.0
# 2                    Housing   1103           0       0.0
# 3                      Goods   1104           0       0.0
# 4                    Transit   1105           0       0.0
# ..                       ...    ...         ...       ...
# 322                In Danger  20089     Urgency   20087.0
# 323          Chronic Illness  20090      Health    1106.0
# 324                  Spouses  20091        Role   20072.0
# 325               Dependents  20092        Role   20072.0
# 326  Intellectual Disability  20093  Disability   20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# g = df.groupby('Survived')

# %%
g = df.groupby('Survived')

# %%
g.sum()
# Out:
#                                                        Name  Pclass  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...    1390
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...     666
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalemale...   8184.67    161
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282347742237736PP 9549113...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16498.1294  C85G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D1...
#
# ...

# %%
g1 = df.groupby('Pclass')

# %%
g1

# %%
g1.sum().T
# Out:
# Pclass                                                    1  \
# Name      Cumings, Mrs. John Bradley (Florence Briggs Th...
# Survived                                                135
# Sex       femalemalefemalemalemalemalefemalemalemalefema...
# Age                                                 7076.42
# SibSp                                                    89
# Parch                                                    77
# Ticket    PC 175991746311378311378819950PC 17601PC 17569...
# Fare                                             18124.3125
# Cabin     C85E46C103A6C23 C25 C27B78D33B30C52B28C83C23 C...
# Embarked  CSSSSCCCSCCSSCSSSCCSSCSSSCSCSSSCCSSCCCCCSSQSSC...
#
# Pclass                                                    2  \
# Name      Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# Survived                                                 87
# Sex       femalefemalemalemalemalemalefemalefemalefemale...
# Age                                                 5168.83
# ...

# %%
df5 = df[['Pclass','Survived','Name']][0:5]

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#    Pclass  Survived                                               Name
# 0       3         0                            Braund, Mr. Owen Harris
# 1       1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3         1                             Heikkinen, Miss. Laina
# 3       3         0                           Allen, Mr. William Henry
# 4       3         0                                   Moran, Mr. James

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6])
# Out:
#    Pclass  Survived                                               Name
# 0       3         0                            Braund, Mr. Owen Harris
# 1       1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3         1                             Heikkinen, Miss. Laina
# 3       3         0                           Allen, Mr. William Henry
# 4       3         0                                   Moran, Mr. James
# 5       1         0                            McCarthy, Mr. Timothy J
# 6       3         0                     Palsson, Master. Gosta Leonard
# 7       3         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8       2         1                Nasser, Mrs. Nicholas (Adele Achem)
# 9       3         1                    Sandstrom, Miss. Marguerite Rut

# %%
df7 = pd.concat([df5,df6],axis=1)

# %%
df7.fillna("rishi")
# Out:
#   Pclass Survived                                               Name  \
# 0    3.0      0.0                            Braund, Mr. Owen Harris
# 1    1.0      1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    3.0      1.0                             Heikkinen, Miss. Laina
# 3    3.0      0.0                           Allen, Mr. William Henry
# 4    3.0      0.0                                   Moran, Mr. James
# 5  rishi    rishi                                              rishi
# 6  rishi    rishi                                              rishi
# 7  rishi    rishi                                              rishi
# 8  rishi    rishi                                              rishi
# 9  rishi    rishi                                              rishi
#
#                                                 Name Survived Pclass
# 0                                              rishi    rishi  rishi
# 1                                              rishi    rishi  rishi
# ...

# %%
df7
# Out:
#    Pclass  Survived                                               Name  \
# 0     3.0       0.0                            Braund, Mr. Owen Harris
# 1     1.0       1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     3.0       1.0                             Heikkinen, Miss. Laina
# 3     3.0       0.0                           Allen, Mr. William Henry
# 4     3.0       0.0                                   Moran, Mr. James
# 5     NaN       NaN                                                NaN
# 6     NaN       NaN                                                NaN
# 7     NaN       NaN                                                NaN
# 8     NaN       NaN                                                NaN
# 9     NaN       NaN                                                NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
data1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago'],'City': ['New York', 'Los Angeles', 'Chicago']})

# %%
data1
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
data2 = pd.DataFrame({
    'Name': ['David', 'Eve', 'Frank'],  'Name': ['David', 'Eve', 'Frank'],
    'Age': [28, 32, 40], 'Age': [28, 32, 40],
    'City': ['Miami', 'Seattle', 'Boston'], 'City': ['Miami', 'Seattle', 'Boston']})

# %%
data2
# Out:
#     Name  Age     City
# 0  David   28    Miami
# 1    Eve   32  Seattle
# 2  Frank   40   Boston

# %%
pd.merge(data1,data2,how='left')
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
pd.merge(data1,data2,how='right')
# Out:
#     Name  Age     City
# 0  David   28    Miami
# 1    Eve   32  Seattle
# 2  Frank   40   Boston

# %%
pd.merge(data1,data2,how='outer')
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   28        Miami
# 4      Eve   32      Seattle
# 5    Frank   40       Boston

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     Name_x  Age_x       City_x Name_y  Age_y   City_y
# 0    Alice     25     New York  David     28    Miami
# 1    Alice     25     New York    Eve     32  Seattle
# 2    Alice     25     New York  Frank     40   Boston
# 3      Bob     30  Los Angeles  David     28    Miami
# 4      Bob     30  Los Angeles    Eve     32  Seattle
# 5      Bob     30  Los Angeles  Frank     40   Boston
# 6  Charlie     35      Chicago  David     28    Miami
# 7  Charlie     35      Chicago    Eve     32  Seattle
# 8  Charlie     35      Chicago  Frank     40   Boston

# %%
df['Fare]'] = df['Fare'].apply(lambda x: x * 82.5)

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3       8.0500
# 4       8.4583
#         ...
# 885    13.0000
# 886    30.0000
# 887    23.4500
# 888    30.0000
# 889     7.7500
# Name: Fare, Length: 890, dtype: float64

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#         Fare]
# 0   598.12500
# 1  5880.87225
# 2   653.81250
# 3   664.12500
# 4   697.80975

# %%
df['Name'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#    Name  Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# 0    23         0       3    male  22.0      1      0         A/5 21171
# 1    51         1       1  female  38.0      1      0          PC 17599
# 2    22         1       3  female  26.0      0      0  STON/O2. 3101282
# 3    24         0       3    male  35.0      0      0            373450
# 4    16         0       3    male   NaN      0      0            330877
#
#       Fare Cabin Embarked       Fare]
# 0   7.2500   NaN        S   598.12500
# 1  71.2833   C85        C  5880.87225
# 2   7.9250   NaN        S   653.81250
# 3   8.0500   NaN        S   664.12500
# 4   8.4583   NaN        Q   697.80975
